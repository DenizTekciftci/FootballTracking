# %%
from ultralytics import YOLO

model = YOLO("models/best.pt")

# %%
results = model.predict("d:/Football/clips/08fd33_4.mp4", save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) d:\Football\clips\08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 160.8ms
# video 1/1 (frame 2/750) d:\Football\clips\08fd33_4.mp4: 384x640 1 ball, 20 players, 3 referees, 7.0ms
# video 1/1 (frame 3/750) d:\Football\clips\08fd33_4.mp4: 384x640 20 players, 3 referees, 7.0ms
# video 1/1 (frame 4/750) d:\Football\clips\08fd33_4.mp4: 384x640 1 ball, 21 players, 3 referees, 7.0ms
# ...

# %%
print(results[0])
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
for box in results[0].boxes:
    print(box)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8625], device='cuda:0')
# data: tensor([[533.7233, 686.4006, 579.3226, 784.5291,   0.8625,   0.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# xywh: tensor([[556.5229, 735.4648,  45.5993,  98.1284]], device='cuda:0')
# xywhn: tensor([[0.2899, 0.6810, 0.0237, 0.0909]], device='cuda:0')
# xyxy: tensor([[533.7233, 686.4006, 579.3226, 784.5291]], device='cuda:0')
# xyxyn: tensor([[0.2780, 0.6356, 0.3017, 0.7264]], device='cuda:0')
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([0.], device='cuda:0')
# conf: tensor([0.8573], device='cuda:0')
# data: tensor([[8.5193e+02, 6.3430e+02, 9.0102e+02, 7.2251e+02, 8.5734e-01, 0.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (1080, 1920)
# shape: torch.Size([1, 6])
# ...
